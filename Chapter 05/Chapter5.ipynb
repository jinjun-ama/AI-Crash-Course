# %% [markdown]
# ## Chapter 5

# %% [markdown]
# ### predictor.py

# %%
# Thompson Sampling for Slot Machines

# Importing the libraries
import numpy as np

# Setting conversion rates and the number of samples
conversionRates = [0.15, 0.04, 0.13, 0.11, 0.05]
N = 10000
d = len(conversionRates)

# Creating the dataset
X = np.zeros((N, d))
for i in range(N):
    for j in range(d):
        if np.random.rand() < conversionRates[j]:
            X[i][j] = 1

# Making arrays to count our losses and wins
nPosReward = np.zeros(d)
nNegReward = np.zeros(d)

# Taking our best slot machine through beta distibution and updating its losses and wins
for i in range(N):
    selected = 0
    maxRandom = 0
    for j in range(d):
        randomBeta = np.random.beta(nPosReward[j] + 1, nNegReward[j] + 1)
        if randomBeta > maxRandom:
            maxRandom = randomBeta
            selected = j
    if X[i][selected] == 1:
        nPosReward[selected] += 1
    else:
        nNegReward[selected] += 1

# Showing which slot machine is considered the best
nSelected = nPosReward + nNegReward 
for i in range(d):
    print('Machine number ' + str(i + 1) + ' was selected ' + str(nSelected[i]) + ' times and got rewards ' + str(nPosReward[i]))
print('Conclusion: Best machine is machine number ' + str(np.argmax(nSelected) + 1) + ' and total rewards is ' + str(np.sum(nPosReward)))

print('-------------------------------')

# Let's try UCB1 algo
sum_rewards_ucb = [0] * 9
numbers_of_selected_ucb = [0] * 9

for n in range(N):
    strategy_us = 0
    max_ucb = sum_rewards_ucb[0] / max(numbers_of_selected_ucb[0],1) + np.sqrt(2*np.log(max(n,1))/max(numbers_of_selected_ucb[0],1))
    for i in range(1, d):
        i_ucb = sum_rewards_ucb[i] / max(numbers_of_selected_ucb[i],1) + np.sqrt(2*np.log(max(n,1))/max(numbers_of_selected_ucb[i],1))
        if i_ucb > max_ucb:
            max_ucb = i_ucb
            strategy_us = i

    sum_rewards_ucb[strategy_us] = sum_rewards_ucb[strategy_us] + X[n, strategy_us]
    numbers_of_selected_ucb[strategy_us] = numbers_of_selected_ucb[strategy_us] + 1

# Showing which slot machine is considered the best
for i in range(d):
    print('Machine number ' + str(i + 1) + ' was selected ' + str(numbers_of_selected_ucb[i]) + ' times and got rewards ' + str(sum_rewards_ucb[i]))
print('Conclusion: Best machine is machine number ' + str(np.argmax(numbers_of_selected_ucb) + 1) + ' and total rewards is ' + str(np.sum(sum_rewards_ucb)))
# Out:
# Machine number 1 was selected 8608.0 times and got rewards 1293.0
# Machine number 2 was selected 64.0 times and got rewards 1.0
# Machine number 3 was selected 1075.0 times and got rewards 125.0
# Machine number 4 was selected 144.0 times and got rewards 9.0
# Machine number 5 was selected 109.0 times and got rewards 5.0
# Conclusion: Best machine is machine number 1 and total rewards is 1433.0
# -------------------------------
# Machine number 1 was selected 4138 times and got rewards 604.0
# Machine number 2 was selected 652 times and got rewards 28.0
# Machine number 3 was selected 2689 times and got rewards 344.0
# Machine number 4 was selected 1917 times and got rewards 216.0
# Machine number 5 was selected 604 times and got rewards 22.0
# Conclusion: Best machine is machine number 1 and total rewards is 1214.0

# %% [markdown]
# ### comparison.py

# %%
# Models comparison

import numpy as np
import pandas as pd

N = [200, 1000, 5000]
D = 20
convRanges = [(0., 0.1), (0., 0.3), (0., 0.5)]

results = list()
for n in N:
    for ranges in convRanges:
        results.append([])
        for d  in range(3, D + 1):
            p1 = 0
            p2 = 0

            for rounds in range(1000):
                
                conversionRates = list()
                for i in range(d):
                    conversionRates.append(np.random.uniform(low = ranges[0], high = ranges[1]))
                    
                X = np.zeros((n,d))
                for i in range(n):
                    for j in range(d):
                        if np.random.rand() < conversionRates[j]:
                            X[i][j] = 1
                
                nPosReward = np.zeros(d)
                nNegReward = np.zeros(d)
                
                for i in range(n):
                    selected = 0
                    maxRandom = 0
                    
                    for j in range(d):
                        randomBeta = np.random.beta(nPosReward[j] + 1, nNegReward[j] + 1)
                        if randomBeta > maxRandom:
                            maxRandom = randomBeta
                            selected = j
                        
                    if X[i][selected] == 1:
                        nPosReward[selected] += 1
                    else:
                        nNegReward[selected] += 1
                
                nSelected = nPosReward + nNegReward
                
                left = n - max(nSelected)
                
                countStandard = np.zeros(d)
                
                x = int(left / d)
                for i in range(x):
                    for j in range(d):
                        if X[i][j] == 1:
                            countStandard[j] += 1
                
                bestStandard = np.argmax(countStandard)
                bestReal = np.argmax(conversionRates)
                bestTS = np.argmax(nSelected)

                if bestTS == bestReal:
                    p1 += 1
                if bestStandard == bestReal:
                    p2 += 1
                
            print('N = ' + str(n) + ' d = ' + str(d) + ' range = ' + str(ranges) + ' | result Thompson Sampling = ' + str(p1) + ' result Standard solution = ' + str(p2))
            results.append([n, ranges, d, p1, p2])
                
df = pd.DataFrame(results)
df.to_excel('results.xlsx', sheet_name = 'Result', index = False)
# Out:
# N = 200 d = 3 range = (0.0, 0.1) | result Thompson Sampling = 650 result Standard solution = 581
# N = 200 d = 4 range = (0.0, 0.1) | result Thompson Sampling = 506 result Standard solution = 463
# N = 200 d = 5 range = (0.0, 0.1) | result Thompson Sampling = 482 result Standard solution = 429
# N = 200 d = 6 range = (0.0, 0.1) | result Thompson Sampling = 405 result Standard solution = 393
# N = 200 d = 7 range = (0.0, 0.1) | result Thompson Sampling = 361 result Standard solution = 315
# N = 200 d = 8 range = (0.0, 0.1) | result Thompson Sampling = 340 result Standard solution = 294
# N = 200 d = 9 range = (0.0, 0.1) | result Thompson Sampling = 300 result Standard solution = 274
# N = 200 d = 10 range = (0.0, 0.1) | result Thompson Sampling = 280 result Standard solution = 232
# N = 200 d = 11 range = (0.0, 0.1) | result Thompson Sampling = 258 result Standard solution = 224
# N = 200 d = 12 range = (0.0, 0.1) | result Thompson Sampling = 223 result Standard solution = 231
# N = 200 d = 13 range = (0.0, 0.1) | result Thompson Sampling = 214 result Standard solution = 184
# N = 200 d = 14 range = (0.0, 0.1) | result Thompson Sampling = 188 result Standard solution = 189
# N = 200 d = 15 range = (0.0, 0.1) | result Thompson Sampling = 153 result Standard solution = 152
# N = 200 d = 16 range = (0.0, 0.1) | result Thompson Sampling = 144 result Standard solution = 163
# N = 200 d = 17 range = (0.0, 0.1) | result Thompson Sampling = 169 result Standard solution = 149
# N = 200 d = 18 range = (0.0, 0.1) | result Thompson Sampling = 147 result Standard solution = 119
# N = 200 d = 19 range = (0.0, 0.1) | result Thompson Sampling = 139 result Standard solution = 151
# N = 200 d = 20 range = (0.0, 0.1) | result Thompson Sampling = 143 result Standard solution = 123
# N = 200 d = 3 range = (0.0, 0.3) | result Thompson Sampling = 768 result Standard solution = 686
# N = 200 d = 4 range = (0.0, 0.3) | result Thompson Sampling = 682 result Standard solution = 579
# N = 200 d = 5 range = (0.0, 0.3) | result Thompson Sampling = 608 result Standard solution = 547
# N = 200 d = 6 range = (0.0, 0.3) | result Thompson Sampling = 536 result Standard solution = 445
# N = 200 d = 7 range = (0.0, 0.3) | result Thompson Sampling = 507 result Standard solution = 440
# N = 200 d = 8 range = (0.0, 0.3) | result Thompson Sampling = 459 result Standard solution = 399
# N = 200 d = 9 range = (0.0, 0.3) | result Thompson Sampling = 418 result Standard solution = 369
# N = 200 d = 10 range = (0.0, 0.3) | result Thompson Sampling = 382 result Standard solution = 342
# N = 200 d = 11 range = (0.0, 0.3) | result Thompson Sampling = 359 result Standard solution = 319
# N = 200 d = 12 range = (0.0, 0.3) | result Thompson Sampling = 331 result Standard solution = 295
# N = 200 d = 13 range = (0.0, 0.3) | result Thompson Sampling = 305 result Standard solution = 282
# N = 200 d = 14 range = (0.0, 0.3) | result Thompson Sampling = 286 result Standard solution = 239
# N = 200 d = 15 range = (0.0, 0.3) | result Thompson Sampling = 288 result Standard solution = 221
# N = 200 d = 16 range = (0.0, 0.3) | result Thompson Sampling = 265 result Standard solution = 210
# N = 200 d = 17 range = (0.0, 0.3) | result Thompson Sampling = 262 result Standard solution = 202
# N = 200 d = 18 range = (0.0, 0.3) | result Thompson Sampling = 261 result Standard solution = 177
# N = 200 d = 19 range = (0.0, 0.3) | result Thompson Sampling = 207 result Standard solution = 160
# N = 200 d = 20 range = (0.0, 0.3) | result Thompson Sampling = 209 result Standard solution = 170
# N = 200 d = 3 range = (0.0, 0.5) | result Thompson Sampling = 817 result Standard solution = 700
# N = 200 d = 4 range = (0.0, 0.5) | result Thompson Sampling = 766 result Standard solution = 631
# N = 200 d = 5 range = (0.0, 0.5) | result Thompson Sampling = 717 result Standard solution = 554
# N = 200 d = 6 range = (0.0, 0.5) | result Thompson Sampling = 659 result Standard solution = 529
# N = 200 d = 7 range = (0.0, 0.5) | result Thompson Sampling = 592 result Standard solution = 463
# N = 200 d = 8 range = (0.0, 0.5) | result Thompson Sampling = 563 result Standard solution = 458
# N = 200 d = 9 range = (0.0, 0.5) | result Thompson Sampling = 512 result Standard solution = 404
# N = 200 d = 10 range = (0.0, 0.5) | result Thompson Sampling = 508 result Standard solution = 369
# N = 200 d = 11 range = (0.0, 0.5) | result Thompson Sampling = 447 result Standard solution = 353
# N = 200 d = 12 range = (0.0, 0.5) | result Thompson Sampling = 434 result Standard solution = 338
# N = 200 d = 13 range = (0.0, 0.5) | result Thompson Sampling = 428 result Standard solution = 304
# N = 200 d = 14 range = (0.0, 0.5) | result Thompson Sampling = 386 result Standard solution = 308
# N = 200 d = 15 range = (0.0, 0.5) | result Thompson Sampling = 362 result Standard solution = 271
# N = 200 d = 16 range = (0.0, 0.5) | result Thompson Sampling = 372 result Standard solution = 269
# N = 200 d = 17 range = (0.0, 0.5) | result Thompson Sampling = 348 result Standard solution = 274
# N = 200 d = 18 range = (0.0, 0.5) | result Thompson Sampling = 316 result Standard solution = 231
# N = 200 d = 19 range = (0.0, 0.5) | result Thompson Sampling = 306 result Standard solution = 233
# N = 200 d = 20 range = (0.0, 0.5) | result Thompson Sampling = 279 result Standard solution = 207
# N = 1000 d = 3 range = (0.0, 0.1) | result Thompson Sampling = 770 result Standard solution = 683
# N = 1000 d = 4 range = (0.0, 0.1) | result Thompson Sampling = 727 result Standard solution = 636
# N = 1000 d = 5 range = (0.0, 0.1) | result Thompson Sampling = 623 result Standard solution = 521
# N = 1000 d = 6 range = (0.0, 0.1) | result Thompson Sampling = 600 result Standard solution = 489
# N = 1000 d = 7 range = (0.0, 0.1) | result Thompson Sampling = 544 result Standard solution = 488
# N = 1000 d = 8 range = (0.0, 0.1) | result Thompson Sampling = 506 result Standard solution = 427
# N = 1000 d = 9 range = (0.0, 0.1) | result Thompson Sampling = 488 result Standard solution = 403
# N = 1000 d = 10 range = (0.0, 0.1) | result Thompson Sampling = 426 result Standard solution = 353
# N = 1000 d = 11 range = (0.0, 0.1) | result Thompson Sampling = 411 result Standard solution = 348
# N = 1000 d = 12 range = (0.0, 0.1) | result Thompson Sampling = 398 result Standard solution = 301
# N = 1000 d = 13 range = (0.0, 0.1) | result Thompson Sampling = 366 result Standard solution = 272
# N = 1000 d = 14 range = (0.0, 0.1) | result Thompson Sampling = 340 result Standard solution = 269
# N = 1000 d = 15 range = (0.0, 0.1) | result Thompson Sampling = 315 result Standard solution = 240
# N = 1000 d = 16 range = (0.0, 0.1) | result Thompson Sampling = 317 result Standard solution = 231
# N = 1000 d = 17 range = (0.0, 0.1) | result Thompson Sampling = 266 result Standard solution = 229
# N = 1000 d = 18 range = (0.0, 0.1) | result Thompson Sampling = 268 result Standard solution = 209
# N = 1000 d = 19 range = (0.0, 0.1) | result Thompson Sampling = 248 result Standard solution = 212
# N = 1000 d = 20 range = (0.0, 0.1) | result Thompson Sampling = 258 result Standard solution = 214
# N = 1000 d = 3 range = (0.0, 0.3) | result Thompson Sampling = 874 result Standard solution = 740
# N = 1000 d = 4 range = (0.0, 0.3) | result Thompson Sampling = 838 result Standard solution = 715
# N = 1000 d = 5 range = (0.0, 0.3) | result Thompson Sampling = 776 result Standard solution = 645
# N = 1000 d = 6 range = (0.0, 0.3) | result Thompson Sampling = 728 result Standard solution = 570
# N = 1000 d = 7 range = (0.0, 0.3) | result Thompson Sampling = 721 result Standard solution = 578
# N = 1000 d = 8 range = (0.0, 0.3) | result Thompson Sampling = 653 result Standard solution = 509
# N = 1000 d = 9 range = (0.0, 0.3) | result Thompson Sampling = 608 result Standard solution = 481
# N = 1000 d = 10 range = (0.0, 0.3) | result Thompson Sampling = 598 result Standard solution = 427
# N = 1000 d = 11 range = (0.0, 0.3) | result Thompson Sampling = 603 result Standard solution = 442
# N = 1000 d = 12 range = (0.0, 0.3) | result Thompson Sampling = 561 result Standard solution = 411
# N = 1000 d = 13 range = (0.0, 0.3) | result Thompson Sampling = 528 result Standard solution = 367
# N = 1000 d = 14 range = (0.0, 0.3) | result Thompson Sampling = 523 result Standard solution = 382
# N = 1000 d = 15 range = (0.0, 0.3) | result Thompson Sampling = 479 result Standard solution = 352
# N = 1000 d = 16 range = (0.0, 0.3) | result Thompson Sampling = 459 result Standard solution = 324
# N = 1000 d = 17 range = (0.0, 0.3) | result Thompson Sampling = 431 result Standard solution = 319
# N = 1000 d = 18 range = (0.0, 0.3) | result Thompson Sampling = 404 result Standard solution = 299
# N = 1000 d = 19 range = (0.0, 0.3) | result Thompson Sampling = 423 result Standard solution = 284
# N = 1000 d = 20 range = (0.0, 0.3) | result Thompson Sampling = 402 result Standard solution = 285
# N = 1000 d = 3 range = (0.0, 0.5) | result Thompson Sampling = 903 result Standard solution = 792
# N = 1000 d = 4 range = (0.0, 0.5) | result Thompson Sampling = 873 result Standard solution = 724
# N = 1000 d = 5 range = (0.0, 0.5) | result Thompson Sampling = 818 result Standard solution = 688
# N = 1000 d = 6 range = (0.0, 0.5) | result Thompson Sampling = 806 result Standard solution = 648
# N = 1000 d = 7 range = (0.0, 0.5) | result Thompson Sampling = 783 result Standard solution = 608
# N = 1000 d = 8 range = (0.0, 0.5) | result Thompson Sampling = 743 result Standard solution = 548
# N = 1000 d = 9 range = (0.0, 0.5) | result Thompson Sampling = 698 result Standard solution = 519
# N = 1000 d = 10 range = (0.0, 0.5) | result Thompson Sampling = 683 result Standard solution = 501
# N = 1000 d = 11 range = (0.0, 0.5) | result Thompson Sampling = 664 result Standard solution = 479
# N = 1000 d = 12 range = (0.0, 0.5) | result Thompson Sampling = 658 result Standard solution = 488
# N = 1000 d = 13 range = (0.0, 0.5) | result Thompson Sampling = 627 result Standard solution = 439
# N = 1000 d = 14 range = (0.0, 0.5) | result Thompson Sampling = 638 result Standard solution = 426
# N = 1000 d = 15 range = (0.0, 0.5) | result Thompson Sampling = 607 result Standard solution = 400
# N = 1000 d = 16 range = (0.0, 0.5) | result Thompson Sampling = 584 result Standard solution = 382
# N = 1000 d = 17 range = (0.0, 0.5) | result Thompson Sampling = 538 result Standard solution = 378
# N = 1000 d = 18 range = (0.0, 0.5) | result Thompson Sampling = 538 result Standard solution = 356
# N = 1000 d = 19 range = (0.0, 0.5) | result Thompson Sampling = 521 result Standard solution = 357
# N = 1000 d = 20 range = (0.0, 0.5) | result Thompson Sampling = 516 result Standard solution = 340
# N = 5000 d = 3 range = (0.0, 0.1) | result Thompson Sampling = 882 result Standard solution = 778
# N = 5000 d = 4 range = (0.0, 0.1) | result Thompson Sampling = 859 result Standard solution = 709
# N = 5000 d = 5 range = (0.0, 0.1) | result Thompson Sampling = 798 result Standard solution = 673
# N = 5000 d = 6 range = (0.0, 0.1) | result Thompson Sampling = 781 result Standard solution = 643
# N = 5000 d = 7 range = (0.0, 0.1) | result Thompson Sampling = 756 result Standard solution = 578
# N = 5000 d = 8 range = (0.0, 0.1) | result Thompson Sampling = 736 result Standard solution = 575
# N = 5000 d = 9 range = (0.0, 0.1) | result Thompson Sampling = 671 result Standard solution = 545
# N = 5000 d = 10 range = (0.0, 0.1) | result Thompson Sampling = 649 result Standard solution = 493
# N = 5000 d = 11 range = (0.0, 0.1) | result Thompson Sampling = 645 result Standard solution = 472
# N = 5000 d = 12 range = (0.0, 0.1) | result Thompson Sampling = 631 result Standard solution = 489
# N = 5000 d = 13 range = (0.0, 0.1) | result Thompson Sampling = 589 result Standard solution = 431
# N = 5000 d = 14 range = (0.0, 0.1) | result Thompson Sampling = 542 result Standard solution = 404
# N = 5000 d = 15 range = (0.0, 0.1) | result Thompson Sampling = 565 result Standard solution = 378
# N = 5000 d = 16 range = (0.0, 0.1) | result Thompson Sampling = 512 result Standard solution = 362
# N = 5000 d = 17 range = (0.0, 0.1) | result Thompson Sampling = 483 result Standard solution = 324
# N = 5000 d = 18 range = (0.0, 0.1) | result Thompson Sampling = 481 result Standard solution = 331
# N = 5000 d = 19 range = (0.0, 0.1) | result Thompson Sampling = 439 result Standard solution = 351
# N = 5000 d = 20 range = (0.0, 0.1) | result Thompson Sampling = 415 result Standard solution = 291
# N = 5000 d = 3 range = (0.0, 0.3) | result Thompson Sampling = 942 result Standard solution = 828
# N = 5000 d = 4 range = (0.0, 0.3) | result Thompson Sampling = 896 result Standard solution = 750
# N = 5000 d = 5 range = (0.0, 0.3) | result Thompson Sampling = 879 result Standard solution = 711
# N = 5000 d = 6 range = (0.0, 0.3) | result Thompson Sampling = 890 result Standard solution = 717
# N = 5000 d = 7 range = (0.0, 0.3) | result Thompson Sampling = 864 result Standard solution = 667
# N = 5000 d = 8 range = (0.0, 0.3) | result Thompson Sampling = 841 result Standard solution = 631
# N = 5000 d = 9 range = (0.0, 0.3) | result Thompson Sampling = 780 result Standard solution = 606
# N = 5000 d = 10 range = (0.0, 0.3) | result Thompson Sampling = 778 result Standard solution = 573
# N = 5000 d = 11 range = (0.0, 0.3) | result Thompson Sampling = 797 result Standard solution = 553
# N = 5000 d = 12 range = (0.0, 0.3) | result Thompson Sampling = 747 result Standard solution = 536
# N = 5000 d = 13 range = (0.0, 0.3) | result Thompson Sampling = 741 result Standard solution = 501
# N = 5000 d = 14 range = (0.0, 0.3) | result Thompson Sampling = 701 result Standard solution = 503
# N = 5000 d = 15 range = (0.0, 0.3) | result Thompson Sampling = 712 result Standard solution = 494
# N = 5000 d = 16 range = (0.0, 0.3) | result Thompson Sampling = 687 result Standard solution = 484
# N = 5000 d = 17 range = (0.0, 0.3) | result Thompson Sampling = 667 result Standard solution = 440
# N = 5000 d = 18 range = (0.0, 0.3) | result Thompson Sampling = 639 result Standard solution = 428
# N = 5000 d = 19 range = (0.0, 0.3) | result Thompson Sampling = 616 result Standard solution = 419
# N = 5000 d = 20 range = (0.0, 0.3) | result Thompson Sampling = 618 result Standard solution = 413
# N = 5000 d = 3 range = (0.0, 0.5) | result Thompson Sampling = 957 result Standard solution = 875
# N = 5000 d = 4 range = (0.0, 0.5) | result Thompson Sampling = 936 result Standard solution = 802
# N = 5000 d = 5 range = (0.0, 0.5) | result Thompson Sampling = 932 result Standard solution = 760
# N = 5000 d = 6 range = (0.0, 0.5) | result Thompson Sampling = 911 result Standard solution = 726
# N = 5000 d = 7 range = (0.0, 0.5) | result Thompson Sampling = 883 result Standard solution = 682
# N = 5000 d = 8 range = (0.0, 0.5) | result Thompson Sampling = 891 result Standard solution = 671
# N = 5000 d = 9 range = (0.0, 0.5) | result Thompson Sampling = 863 result Standard solution = 633
# N = 5000 d = 10 range = (0.0, 0.5) | result Thompson Sampling = 845 result Standard solution = 610
# N = 5000 d = 11 range = (0.0, 0.5) | result Thompson Sampling = 843 result Standard solution = 599
# N = 5000 d = 12 range = (0.0, 0.5) | result Thompson Sampling = 807 result Standard solution = 573
# N = 5000 d = 13 range = (0.0, 0.5) | result Thompson Sampling = 799 result Standard solution = 589
# N = 5000 d = 14 range = (0.0, 0.5) | result Thompson Sampling = 795 result Standard solution = 566
# N = 5000 d = 15 range = (0.0, 0.5) | result Thompson Sampling = 763 result Standard solution = 510
# N = 5000 d = 16 range = (0.0, 0.5) | result Thompson Sampling = 782 result Standard solution = 532
# N = 5000 d = 17 range = (0.0, 0.5) | result Thompson Sampling = 783 result Standard solution = 514
# N = 5000 d = 18 range = (0.0, 0.5) | result Thompson Sampling = 739 result Standard solution = 498
# N = 5000 d = 19 range = (0.0, 0.5) | result Thompson Sampling = 701 result Standard solution = 468
# N = 5000 d = 20 range = (0.0, 0.5) | result Thompson Sampling = 744 result Standard solution = 454
